# %%
# np.random.rand()

# %%
import numpy as np
np.random.rand()
# Out:
# 0.6477689993961935

# %% [markdown]
#  if you are using different algorythms, the rand system uses the same random numbers, so it helps to use same statistical random data

# %%
np.random.seed(123)

# %%
np.random.rand()
# Out:
# 0.6964691855978616

# %%
np.random.rand()
# Out:
# 0.28613933495037946

# %%
np.random.seed(123)

# %%
np.random.rand()
# Out:
# 0.6964691855978616

# %%
np.random.rand()
# Out:
# 0.28613933495037946

# %%
# lets use this in a coin toss
np.random.seed(123)
coin=np.random.randint(0,2)
print(coin)
# Out:
# 0

# %% [markdown]
# seed(): sets the random seed, so that your results are the reproducible between simulations. As an argument, it takes an integer of your choosing. If you call the function, no output will be generated.
#
# rand(): if you don't specify any arguments, it generates a random float between zero and one.

# %% [markdown]
# lets play a statistics simulation game:
# you are in a tower at step 50.
# If dice is 1 or 2, you go one step down.
# if dice is 3, 4 or 5, you go one step up.
# Else, you throw the dice again. The number of eyes is the number of steps you go up.

# %%
dice=np.random.randint(1,7)
step=50
if dice==1 or dice==2:
    step-=1
elif dice==3 or dice==4 or dice==5:
    step+=1
else:
    dice=np.random.randint(1,7)
    step=step+dice
print(step)
print(dice)
# Out:
# 53
# 3

# %% [markdown]
# lets play also a heads or tails game, that the results are stored

# %%
#with .seed() method always same random results
np.random.seed(123)
outcomes=[]
for i in range(10):
    coin=np.random.randint(0,2)
    if coin==0:
        outcomes.append("Heads")
    else:
        outcomes.append("Tails")
print(outcomes)
# Out:
# ['Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads']

# %%
# now dont wrtite .seed() method, the results will change
outcomes=[]
for i in range(10):
    coin=np.random.randint(0,2)
    if coin==0:
        outcomes.append("Heads")
    else:
        outcomes.append("Tails")
print(outcomes)
# Out:
# ['Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads']

# %%
# lets simulate this with a random walk game

random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        
        # Replace below: use max to make sure step can't go below 0
        step = max(0,step - 1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

print(random_walk)
# Out:
# [0, 0, 0, 1, 6, 5, 4, 5, 4, 5, 6, 7, 8, 9, 8, 9, 8, 9, 10, 11, 12, 11, 15, 16, 15, 16, 15, 16, 17, 18, 19, 20, 21, 22, 25, 26, 27, 28, 33, 34, 38, 39, 38, 39, 40, 39, 40, 41, 43, 44, 45, 44, 43, 44, 45, 44, 43, 44, 45, 47, 46, 45, 46, 45, 46, 47, 48, 50, 49, 50, 51, 52, 53, 54, 53, 52, 53, 52, 53, 54, 53, 56, 57, 58, 59, 58, 59, 60, 64, 63, 62, 64, 63, 64, 66, 67, 68, 73, 72, 73, 74]

# %%
# we can visualize the walk
random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        
        # Replace below: use max to make sure step can't go below 0
        step = max(0,step - 1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)
    
import matplotlib.pyplot as plt
plt.plot(random_walk)
plt.show()

print(random_walk)
# Out:
# [0, 1, 2, 3, 2, 7, 8, 9, 10, 9, 8, 7, 6, 5, 6, 7, 8, 14, 13, 12, 11, 12, 13, 14, 13, 14, 15, 14, 19, 20, 19, 18, 17, 16, 17, 16, 15, 17, 18, 21, 22, 24, 25, 26, 27, 26, 25, 26, 27, 28, 29, 28, 29, 30, 31, 34, 35, 36, 35, 36, 35, 36, 37, 38, 42, 41, 40, 41, 42, 43, 42, 43, 42, 43, 45, 50, 49, 50, 51, 52, 53, 54, 55, 54, 55, 56, 57, 59, 61, 60, 61, 62, 65, 64, 65, 64, 65, 66, 67, 66, 67]

# %% [markdown]
# To get an idea about how big your chances are of reaching 60 steps, you can repeatedly simulate the random walk and collect the results. That's exactly what you'll do in this exercise.

# %%
# numpy and matplotlib imported, seed set.

# initialize and populate all_walks
all_walks = []
for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to Numpy array: np_aw
np_aw=np.array(all_walks)

# Plot np_aw and show
plt.plot(np_aw)
